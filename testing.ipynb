# %%
from collections import Counter
import socket
import time
import ray
ray.init(address="auto")

@ray.remote
def function_with_an_argument(value):
    return value+5 


# You can pass an object ref as an argument to another Ray remote function.
obj_ref2 = function_with_an_argument.remote(45)
print(ray.get(obj_ref2))

ray.shutdown()
# Out:
# 2021-06-05 04:19:18,403	INFO worker.py:640 -- Connecting to existing Ray cluster at address: 192.168.1.34:6379
# 50

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.color import rgb2gray
from skimage.transform import rescale
from scipy.signal import convolve2d
import socket 
import sys
import time
from skimage import io
from matplotlib import image
from matplotlib import pyplot




# load image as pixel array
image = image.imread('./dataset/python.png')
pyplot.imshow(image)
pyplot.show()



def rgb_convolve2d(image, kernel=np.array([[0,1,0], [1,-4,1], [0,1,0]])):
    red = convolve2d(image[:,:,0], kernel)
    green = convolve2d(image[:,:,1], kernel)
    blue = convolve2d(image[:,:,2], kernel)
    return np.stack([red, green, blue], axis=2)

# %%
out=rgb_convolve2d(image)
pyplot.imshow(out)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
